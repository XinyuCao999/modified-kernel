# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot,plot
from plotly.subplots import make_subplots
import datetime
from BO_base import plot_bo_comparison

date=str(datetime.date.today())[5:]
date="09-23"
save_path="BO/"+date+"data_list.npy"   #Aquisition: UCB
save_path="BO/"+date+"data_list_1.npy"  #Aquisition: EI
info_dict=np.load(save_path,allow_pickle=True).item()

# %%
plot_bo_comparison(info_dict,reference_max=191.02,date=date,withdraw_model_index=[],draw_initial_point=True,draw_iter_step=10,save_path=None,yaxis_lower_bound=3)
