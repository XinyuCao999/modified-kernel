# %%
import os
import sys
path_win=r"C:\Users\cheese_cake\Desktop\jenny\课题进展\25_06 pysical-informed BO\3vdv"
path_mac=r"/Users/jenny/Nutstore Files/课题进展/25_06 pysical-informed BO/3vdv"
os.chdir(path_mac)
sys.path.append(os.path.dirname(path_mac))
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot,plot
from plotly.subplots import make_subplots
import datetime


from BO_base import plot_bo_comparison

date=str(datetime.date.today())[5:]
date="09-23"
save_path="BO/"+date+"data_list.npy"  #Aquisition: UCB
# save_path="BO/"+date+"data_list_1.npy"  #Aquisition: EI
info_dict=np.load(save_path,allow_pickle=True).item()

# %%
plot_bo_comparison(info_dict,reference_max=0.7888299971987257,date=date,withdraw_model_index=[],draw_initial_point=True,save_path=None,yaxis_lower_bound=2.5)
